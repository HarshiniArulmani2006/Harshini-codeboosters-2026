# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshiniArulmani2006/Harshini-codeboosters-2026/blob/main/Day_1_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/student_performance.csv')

# %%
print(df)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
print(f"Total Students: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
print(f"Department Count: {df['department'].nunique()}")
# Out:
# Total Students: 30
# Total Columns: 13
# Department Count: 4

# %%
print(df['department'].value_counts())
# Out:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print(f"Highest Math Score:{df['math_score'].max()}")
print(f"Lowest Math Score:{df['math_score'].min()}")
print(f"Average Math Score:{df['math_score'].mean().round(2)}")
print(f"Average Programming Score:{df['programming_score'].mean().round(2)}")
print(f"Average Attendance Percentage:{df['attendance_percentage'].mean().round(2)}%")
# Out:
# Highest Math Score:95
# Lowest Math Score:56
# Average Math Score:76.07
# Average Programming Score:67.6
# Average Attendance Percentage:84.5%

# %%
df['total_score']=(df['math_score']+df['science_score']+df['english_score']+df['programming_score'])
gender_score = df.groupby('gender')['total_score'].mean().round(2)
print(gender_score)
# Out:
# gender
# Female    310.67
# Male      280.67
# Name: total_score, dtype: float64

# %%
top5=df.sort_values('total_score',ascending=False).head(5)
for index, row in top5.iterrows():
    print(f"{row['name']:<20}  {row['department']:<18}  Score:{row['total_score']}")
# Out:
# Ananya Das            Computer Science    Score:371
# Tanvi Mehta           Computer Science    Score:367
# Akanksha Yadav        Computer Science    Score:365
# Arjun Nair            Computer Science    Score:356
# Divya Singh           Computer Science    Score:356

# %%
low_attendance=df[df['attendance_percentage']<75][['name','department','attendance_percentage']]
if len(low_attendance)>0:
  print(low_attendance.to_string(index=False))
else:
  print("All Students have attendance above 75%")
print("Report Complete")
# Out:
#          name  department  attendance_percentage
#   Meera Joshi Electronics                     72
#  Rahul Mishra  Mechanical                     68
#  Manoj Pandey       Civil                     65
# Harish Pillai Electronics                     74
#  Sanjay Dubey       Civil                     70
# Sunita Pillai       Civil                     73
# Report Complete

# %%
electronics_students = df[df['department'] == 'Electronics']
print("1. Electronics Department Students:",
      len(electronics_students))
# Out:
# 1. Electronics Department Students: 6

# %%
female_students = df[df['gender'] == 'Female']
print("2. Average Attendance of Female Students:",
      round(female_students['attendance_percentage'].mean(), 2))
# Out:
# 2. Average Attendance of Female Students: 88.53

# %%
lowest_programming = df.loc[df['programming_score'].idxmin()]
print("3. Student with Lowest Programming Score:",
      lowest_programming['name'])
# Out:
# 3. Student with Lowest Programming Score: Manoj Pandey

# %%
math_above_80 = df[df['math_score'] > 80]
print("4. Students Scored Above 80 in Math:",
      len(math_above_80))
# Out:
# 4. Students Scored Above 80 in Math: 11

# %%
# Create total_score column
df['total_score']=(df['math_score']+df['science_score']+df['english_score']+df['programming_score'])
# Students with attendance above 90%
high_attendance = df[df['attendance_percentage'] > 90]
# Average total score
print("Average Total Score:",
      high_attendance['total_score'].mean())
# Out:
# Average Total Score: 335.8
